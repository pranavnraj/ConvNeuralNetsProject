# %%
import matplotlib.pyplot as plt
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as datasets
import torch.utils.data as data
from torchvision.utils import make_grid

import torchvision.transforms as transforms
import torchvision
import os

import alex_net
import vgg16
import resnet
import googlenet
from train import train_model

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([0.4802, 0.4481, 0.3975], [0.2302, 0.2265, 0.2262]),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([0.4802, 0.4481, 0.3975], [0.2302, 0.2265, 0.2262]),
    ]),
    'test': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([0.4802, 0.4481, 0.3975], [0.2302, 0.2265, 0.2262]),
    ])
}

data_dir = 'tiny-imagenet-200/'

num_workers = {
    'train' : 100,
    'val'   : 0,
    'test'  : 0
}

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val','test']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=100,
                                             shuffle=True,num_workers=num_workers[x])
              for x in ['train', 'val', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val', 'test']}

# %%
def imshow(img):
    img = img.numpy().transpose((1, 2, 0))
    img = np.clip(img, 0, 1)
    plt.imshow(img)

images, labels = next(iter(dataloaders['train']))
print(labels)
grid_img = make_grid(images[:4], nrow=4)
imshow(grid_img)

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cuda:0

# %%
#net = alex_net.AlexNet()     # Create the network instance.
#net = vgg16.VGG()
net = resnet.resnet18()
#net = resnet.resnet50()
#net = googlenet.google_net()
net.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicIdentityBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (downsample): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       )
#     )
#     (1): BasicIdentityBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicIdentityBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       )
#     )
#     (1): BasicIdentityBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicIdentityBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       )
#     )
#     (1): BasicIdentityBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicIdentityBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       )
#     )
#     (1): BasicIdentityBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=200, bias=True)
# )

# %%
loss_func = nn.CrossEntropyLoss()
opt = optim.SGD(net.parameters(), lr = 0.005, momentum=0.9)

# %%
#avg_losses = train_model(net, opt, loss_func, dataloaders, device, epochs=13)
avg_losses = []   # Avg. losses.
print_freq = 100
epochs = 13

for epoch in range(epochs):  # Loop over the dataset multiple times.
    running_loss = 0.0       # Initialize running loss.
    for i, (inputs, labels) in enumerate(dataloaders['train']):

        net.train()

        # Move the inputs to the specified device.
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the parameter gradients.
        opt.zero_grad()

        # Forward step.
        outputs = net(inputs)
        loss = loss_func(outputs, labels)

        # Backward step.
        loss.backward()

        # Optimization step (update the parameters).
        opt.step()

        # Print statistics.
        running_loss += loss.item()
        if i % print_freq == print_freq - 1: # Print every several mini-batches.
            avg_loss = running_loss / print_freq
            print('[epoch: {}, i: {:5d}] avg mini-batch loss: {:.3f}'.format(
                epoch, i, avg_loss))
            avg_losses.append(avg_loss)
            running_loss = 0.0

print('Finished Training.')
# Out:
# [epoch: 0, i:    99] avg mini-batch loss: 5.296
# [epoch: 0, i:   199] avg mini-batch loss: 5.038
# [epoch: 0, i:   299] avg mini-batch loss: 4.875
# [epoch: 0, i:   399] avg mini-batch loss: 4.733
# [epoch: 0, i:   499] avg mini-batch loss: 4.606
# [epoch: 0, i:   599] avg mini-batch loss: 4.490
# [epoch: 0, i:   699] avg mini-batch loss: 4.403
# [epoch: 0, i:   799] avg mini-batch loss: 4.298
# [epoch: 0, i:   899] avg mini-batch loss: 4.224
# [epoch: 0, i:   999] avg mini-batch loss: 4.123
# [epoch: 1, i:    99] avg mini-batch loss: 3.947
# [epoch: 1, i:   199] avg mini-batch loss: 3.875
# [epoch: 1, i:   299] avg mini-batch loss: 3.860
# [epoch: 1, i:   399] avg mini-batch loss: 3.782
# [epoch: 1, i:   499] avg mini-batch loss: 3.754
# [epoch: 1, i:   599] avg mini-batch loss: 3.707
# [epoch: 1, i:   699] avg mini-batch loss: 3.671
# [epoch: 1, i:   799] avg mini-batch loss: 3.651
# [epoch: 1, i:   899] avg mini-batch loss: 3.617
# [epoch: 1, i:   999] avg mini-batch loss: 3.603
# [epoch: 2, i:    99] avg mini-batch loss: 3.330
# [epoch: 2, i:   199] avg mini-batch loss: 3.331
# [epoch: 2, i:   299] avg mini-batch loss: 3.315
# [epoch: 2, i:   399] avg mini-batch loss: 3.290
# [epoch: 2, i:   499] avg mini-batch loss: 3.322
# [epoch: 2, i:   599] avg mini-batch loss: 3.269
# [epoch: 2, i:   699] avg mini-batch loss: 3.266
# [epoch: 2, i:   799] avg mini-batch loss: 3.271
# [epoch: 2, i:   899] avg mini-batch loss: 3.211
# [epoch: 2, i:   999] avg mini-batch loss: 3.241
# [epoch: 3, i:    99] avg mini-batch loss: 2.885
# [epoch: 3, i:   199] avg mini-batch loss: 2.887
# [epoch: 3, i:   299] avg mini-batch loss: 2.914
# [epoch: 3, i:   399] avg mini-batch loss: 2.964
# [epoch: 3, i:   499] avg mini-batch loss: 2.920
# [epoch: 3, i:   599] avg mini-batch loss: 2.953
# [epoch: 3, i:   699] avg mini-batch loss: 2.967
# [epoch: 3, i:   799] avg mini-batch loss: 2.929
# [epoch: 3, i:   899] avg mini-batch loss: 2.934
# [epoch: 3, i:   999] avg mini-batch loss: 2.919
# [epoch: 4, i:    99] avg mini-batch loss: 2.515
# [epoch: 4, i:   199] avg mini-batch loss: 2.525
# [epoch: 4, i:   299] avg mini-batch loss: 2.539
# [epoch: 4, i:   799] avg mini-batch loss: 2.648
# [epoch: 4, i:   899] avg mini-batch loss: 2.634
# [epoch: 4, i:   999] avg mini-batch loss: 2.652
# [epoch: 5, i:    99] avg mini-batch loss: 2.105
# [epoch: 5, i:   199] avg mini-batch loss: 2.119
# [epoch: 5, i:   299] avg mini-batch loss: 2.140
# [epoch: 5, i:   399] avg mini-batch loss: 2.193
# [epoch: 5, i:   499] avg mini-batch loss: 2.228
# [epoch: 5, i:   599] avg mini-batch loss: 2.271
# [epoch: 5, i:   699] avg mini-batch loss: 2.278
# [epoch: 5, i:   799] avg mini-batch loss: 2.319
# [epoch: 5, i:   899] avg mini-batch loss: 2.297
# [epoch: 5, i:   999] avg mini-batch loss: 2.351
# [epoch: 6, i:    99] avg mini-batch loss: 1.689
# [epoch: 6, i:   199] avg mini-batch loss: 1.692
# [epoch: 6, i:   299] avg mini-batch loss: 1.722
# [epoch: 6, i:   399] avg mini-batch loss: 1.783
# [epoch: 6, i:   499] avg mini-batch loss: 1.816
# [epoch: 6, i:   599] avg mini-batch loss: 1.920
# [epoch: 6, i:   699] avg mini-batch loss: 1.976
# [epoch: 6, i:   799] avg mini-batch loss: 1.970
# [epoch: 6, i:   899] avg mini-batch loss: 2.037
# [epoch: 6, i:   999] avg mini-batch loss: 2.019
# [epoch: 7, i:    99] avg mini-batch loss: 1.299
# [epoch: 7, i:   199] avg mini-batch loss: 1.286
# [epoch: 7, i:   299] avg mini-batch loss: 1.296
# [epoch: 7, i:   399] avg mini-batch loss: 1.391
# [epoch: 7, i:   499] avg mini-batch loss: 1.450
# [epoch: 7, i:   599] avg mini-batch loss: 1.507
# [epoch: 7, i:   699] avg mini-batch loss: 1.573
# [epoch: 7, i:   799] avg mini-batch loss: 1.572
# [epoch: 7, i:   899] avg mini-batch loss: 1.648
# [epoch: 7, i:   999] avg mini-batch loss: 1.669
# [epoch: 8, i:    99] avg mini-batch loss: 0.910
# [epoch: 8, i:   199] avg mini-batch loss: 0.866
# [epoch: 8, i:   299] avg mini-batch loss: 0.920
# [epoch: 8, i:   399] avg mini-batch loss: 0.975
# [epoch: 8, i:   499] avg mini-batch loss: 1.001
# [epoch: 8, i:   599] avg mini-batch loss: 1.084
# [epoch: 8, i:   699] avg mini-batch loss: 1.152
# [epoch: 8, i:   799] avg mini-batch loss: 1.205
# [epoch: 8, i:   899] avg mini-batch loss: 1.305
# [epoch: 8, i:   999] avg mini-batch loss: 1.321
# [epoch: 9, i:    99] avg mini-batch loss: 0.598
# [epoch: 9, i:   199] avg mini-batch loss: 0.532
# [epoch: 9, i:   299] avg mini-batch loss: 0.536
# [epoch: 9, i:   399] avg mini-batch loss: 0.555
# [epoch: 9, i:   499] avg mini-batch loss: 0.614
# [epoch: 9, i:   999] avg mini-batch loss: 0.929
# [epoch: 10, i:    99] avg mini-batch loss: 0.388
# [epoch: 10, i:   199] avg mini-batch loss: 0.313
# [epoch: 10, i:   299] avg mini-batch loss: 0.318
# [epoch: 10, i:   399] avg mini-batch loss: 0.310
# [epoch: 10, i:   499] avg mini-batch loss: 0.345
# [epoch: 10, i:   599] avg mini-batch loss: 0.366
# [epoch: 10, i:   699] avg mini-batch loss: 0.375
# [epoch: 10, i:   799] avg mini-batch loss: 0.386
# [epoch: 10, i:   899] avg mini-batch loss: 0.431
# [epoch: 10, i:   999] avg mini-batch loss: 0.479
# [epoch: 11, i:    99] avg mini-batch loss: 0.196
# [epoch: 11, i:   199] avg mini-batch loss: 0.157
# [epoch: 11, i:   299] avg mini-batch loss: 0.147
# [epoch: 11, i:   399] avg mini-batch loss: 0.141
# [epoch: 11, i:   499] avg mini-batch loss: 0.137
# [epoch: 11, i:   599] avg mini-batch loss: 0.148
# [epoch: 11, i:   699] avg mini-batch loss: 0.156
# [epoch: 11, i:   799] avg mini-batch loss: 0.158
# [epoch: 11, i:   899] avg mini-batch loss: 0.171
# [epoch: 11, i:   999] avg mini-batch loss: 0.186
# [epoch: 12, i:    99] avg mini-batch loss: 0.075
# [epoch: 12, i:   199] avg mini-batch loss: 0.060
# [epoch: 12, i:   299] avg mini-batch loss: 0.050
# [epoch: 12, i:   399] avg mini-batch loss: 0.054
# [epoch: 12, i:   499] avg mini-batch loss: 0.051
# [epoch: 12, i:   599] avg mini-batch loss: 0.042
# [epoch: 12, i:   699] avg mini-batch loss: 0.048
# [epoch: 12, i:   799] avg mini-batch loss: 0.047
# [epoch: 12, i:   899] avg mini-batch loss: 0.049
# [epoch: 12, i:   999] avg mini-batch loss: 0.047
# Finished Training.

# %%
plt.plot(avg_losses)
plt.xlabel('mini-batch index / {}'.format(print_freq))
plt.ylabel('avg. mini-batch loss')
plt.show()

# %%
# Get test accuracy.
correct = 0
total = 0
with torch.no_grad():
    for i, data in enumerate(dataloaders['test']):
        net.eval()
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 24 %
